# %%
import random
import numpy as np
from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module [citypy imported in first cell]
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 715

# %% [markdown]
# #### Perform an API call with the OpenWeatherMap

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# #### Retrieve the following information from that API Call
# ###### Latitude and longitude
# ###### Maximum temperature
# ###### Percent humidity
# ###### Percent cloudiness
# ###### Wind speed
# ###### Weather description (for example, clouds, fog, light rain, clear sky)

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    time.sleep(1)
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | college
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | katsuura
# Processing Record 12 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 1 | toamasina
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | atambua
# Processing Record 18 of Set 1 | portales
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 1 | argentan
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | ushibuka
# Processing Record 31 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | kouango
# Processing Record 35 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 1 | ceahlau
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | vizinga
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | padang
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | tautira
# Processing Record 48 of Set 1 | boguchany
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | malazgirt
# Processing Record 2 of Set 2 | zaoyang
# Processing Record 3 of Set 2 | conceicao do araguaia
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | skjervoy
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | gamba
# Processing Record 9 of Set 2 | tres arroyos
# Processing Record 10 of Set 2 | tessalit
# Processing Record 11 of Set 2 | bengkulu
# Processing Record 12 of Set 2 | carutapera
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | lhuntshi
# City not found. Skipping...
# Processing Record 15 of Set 2 | ancud
# Processing Record 16 of Set 2 | chapais
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | lakes entrance
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | kahului
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | northam
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | necochea
# Processing Record 26 of Set 2 | fayaoue
# Processing Record 27 of Set 2 | dhidhdhoo
# Processing Record 28 of Set 2 | labuhan
# Processing Record 29 of Set 2 | lafia
# Processing Record 30 of Set 2 | kyren
# Processing Record 31 of Set 2 | oranjemund
# Processing Record 32 of Set 2 | los llanos de aridane
# Processing Record 33 of Set 2 | burnie
# Processing Record 34 of Set 2 | faya
# Processing Record 35 of Set 2 | east london
# Processing Record 36 of Set 2 | san borja
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | toora-khem
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | mwene-ditu
# Processing Record 43 of Set 2 | bubaque
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 2 | tabou
# Processing Record 47 of Set 2 | vilhena
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | mattru
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | rio gallegos
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | jacareacanga
# Processing Record 5 of Set 3 | viru
# Processing Record 6 of Set 3 | lebu
# Processing Record 7 of Set 3 | praia da vitoria
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | belaya gora
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | balkhash
# Processing Record 13 of Set 3 | mmabatho
# Processing Record 14 of Set 3 | filingue
# Processing Record 15 of Set 3 | gillette
# Processing Record 16 of Set 3 | maldonado
# Processing Record 17 of Set 3 | kemijarvi
# Processing Record 18 of Set 3 | kudat
# Processing Record 19 of Set 3 | belle fourche
# Processing Record 20 of Set 3 | vanimo
# Processing Record 21 of Set 3 | mayumba
# Processing Record 22 of Set 3 | taoudenni
# Processing Record 23 of Set 3 | alta floresta
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 3 | mahibadhoo
# Processing Record 28 of Set 3 | havre
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | chagoda
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | bone
# Processing Record 34 of Set 3 | townsville
# Processing Record 35 of Set 3 | peniche
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | aksarka
# Processing Record 38 of Set 3 | jaroslaw
# Processing Record 39 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 3 | ponta delgada
# Processing Record 41 of Set 3 | berlevag
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | mubi
# Processing Record 44 of Set 3 | mecca
# Processing Record 45 of Set 3 | kiunga
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | sola
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 3 | grindavik
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | mount isa
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | ereymentau
# Processing Record 5 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 6 of Set 4 | fortuna
# Processing Record 7 of Set 4 | batagay
# Processing Record 8 of Set 4 | itoman
# Processing Record 9 of Set 4 | caravelas
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | hofn
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | coquimbo
# Processing Record 14 of Set 4 | muros
# Processing Record 15 of Set 4 | bintulu
# Processing Record 16 of Set 4 | pare
# Processing Record 17 of Set 4 | puro
# Processing Record 18 of Set 4 | yellowknife
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | tongling
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 4 | hovd
# Processing Record 26 of Set 4 | pemberton
# Processing Record 27 of Set 4 | pondicherry
# Processing Record 28 of Set 4 | anadyr
# Processing Record 29 of Set 4 | rincon
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | najran
# Processing Record 32 of Set 4 | verkhnevilyuysk
# Processing Record 33 of Set 4 | kismayo
# Processing Record 34 of Set 4 | arman
# Processing Record 35 of Set 4 | mananjary
# Processing Record 36 of Set 4 | bayir
# Processing Record 37 of Set 4 | beringovskiy
# Processing Record 38 of Set 4 | pushkino
# Processing Record 39 of Set 4 | cape town
# Processing Record 40 of Set 4 | sistranda
# Processing Record 41 of Set 4 | goderich
# Processing Record 42 of Set 4 | paracale
# Processing Record 43 of Set 4 | sao joao da barra
# Processing Record 44 of Set 4 | sinnamary
# Processing Record 45 of Set 4 | prince rupert
# Processing Record 46 of Set 4 | baiyin
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | pevek
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 50 of Set 4 | kruisfontein
# Processing Record 1 of Set 5 | nabire
# Processing Record 2 of Set 5 | ilfracombe
# Processing Record 3 of Set 5 | ishigaki
# Processing Record 4 of Set 5 | valparaiso
# Processing Record 5 of Set 5 | palora
# Processing Record 6 of Set 5 | bonavista
# Processing Record 7 of Set 5 | tacna
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | lingao
# Processing Record 10 of Set 5 | takoradi
# Processing Record 11 of Set 5 | estelle
# Processing Record 12 of Set 5 | north myrtle beach
# Processing Record 13 of Set 5 | hasaki
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | astorga
# Processing Record 16 of Set 5 | the pas
# Processing Record 17 of Set 5 | bardiyah
# Processing Record 18 of Set 5 | oranjestad
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | bonthe
# Processing Record 21 of Set 5 | visby
# Processing Record 22 of Set 5 | sao desiderio
# Processing Record 23 of Set 5 | saint george
# Processing Record 24 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 5 | half moon bay
# Processing Record 26 of Set 5 | ixtapa
# Processing Record 27 of Set 5 | ulladulla
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | kuybysheve
# Processing Record 30 of Set 5 | colares
# Processing Record 31 of Set 5 | kanker
# Processing Record 32 of Set 5 | tual
# Processing Record 33 of Set 5 | maniitsoq
# Processing Record 34 of Set 5 | muramvya
# Processing Record 35 of Set 5 | ranapur
# Processing Record 36 of Set 5 | shelburne
# Processing Record 37 of Set 5 | seaside
# Processing Record 38 of Set 5 | waipawa
# Processing Record 39 of Set 5 | kashi
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | farmington
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | muisne
# Processing Record 45 of Set 5 | manzhouli
# Processing Record 46 of Set 5 | yar-sale
# Processing Record 47 of Set 5 | ayagoz
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | cherskiy
# Processing Record 50 of Set 5 | haines junction
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 6 | darnah
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | iqaluit
# Processing Record 5 of Set 6 | umm lajj
# Processing Record 6 of Set 6 | lohja
# Processing Record 7 of Set 6 | hokitika
# Processing Record 8 of Set 6 | camana
# Processing Record 9 of Set 6 | marzuq
# Processing Record 10 of Set 6 | wajima
# Processing Record 11 of Set 6 | bambanglipuro
# Processing Record 12 of Set 6 | hermiston
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | kaitangata
# Processing Record 15 of Set 6 | kadhan
# Processing Record 16 of Set 6 | vadlapudi
# Processing Record 17 of Set 6 | lazaro cardenas
# Processing Record 18 of Set 6 | itarema
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | kenai
# Processing Record 21 of Set 6 | cam ranh
# Processing Record 22 of Set 6 | matadi
# Processing Record 23 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 6 | zaysan
# Processing Record 25 of Set 6 | mar del plata
# Processing Record 26 of Set 6 | tuktoyaktuk
# Processing Record 27 of Set 6 | geraldton
# Processing Record 28 of Set 6 | khandyga
# Processing Record 29 of Set 6 | shubarkuduk
# Processing Record 30 of Set 6 | kokstad
# Processing Record 31 of Set 6 | severo-kurilsk
# Processing Record 32 of Set 6 | were ilu
# Processing Record 33 of Set 6 | saint-pierre
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | ballina
# Processing Record 36 of Set 6 | seoul
# Processing Record 37 of Set 6 | te anau
# Processing Record 38 of Set 6 | awjilah
# Processing Record 39 of Set 6 | port-cartier
# Processing Record 40 of Set 6 | roma
# Processing Record 41 of Set 6 | macherla
# Processing Record 42 of Set 6 | nizhniy baskunchak
# Processing Record 43 of Set 6 | maxixe
# Processing Record 44 of Set 6 | ranong
# Processing Record 45 of Set 6 | puerto baquerizo moreno
# Processing Record 46 of Set 6 | madera
# Processing Record 47 of Set 6 | porto santo
# Processing Record 48 of Set 6 | evensk
# Processing Record 49 of Set 6 | cairns
# Processing Record 50 of Set 6 | chokurdakh
# Processing Record 1 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | port augusta
# Processing Record 3 of Set 7 | port hardy
# Processing Record 4 of Set 7 | mehamn
# Processing Record 5 of Set 7 | north bend
# Processing Record 6 of Set 7 | walvis bay
# Processing Record 7 of Set 7 | rio grande
# Processing Record 8 of Set 7 | harper
# Processing Record 9 of Set 7 | saurimo
# Processing Record 10 of Set 7 | jalu
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | buchanan
# Processing Record 13 of Set 7 | praia
# Processing Record 14 of Set 7 | krivosheino
# Processing Record 15 of Set 7 | champerico
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | conde
# Processing Record 18 of Set 7 | fort frances
# Processing Record 19 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 20 of Set 7 | shunyi
# Processing Record 21 of Set 7 | sudak
# Processing Record 22 of Set 7 | henties bay
# Processing Record 23 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 7 | camacha
# Processing Record 25 of Set 7 | fort nelson
# Processing Record 26 of Set 7 | colchester
# Processing Record 27 of Set 7 | cururupu
# Processing Record 28 of Set 7 | yantzaza
# Processing Record 29 of Set 7 | moron
# Processing Record 30 of Set 7 | bose
# Processing Record 31 of Set 7 | shenjiamen
# Processing Record 32 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 7 | takhtamygda
# Processing Record 34 of Set 7 | phek
# Processing Record 35 of Set 7 | barranquilla
# Processing Record 36 of Set 7 | salalah
# Processing Record 37 of Set 7 | port lincoln
# Processing Record 38 of Set 7 | maloy
# Processing Record 39 of Set 7 | chumikan
# Processing Record 40 of Set 7 | inuvik
# Processing Record 41 of Set 7 | khani
# Processing Record 42 of Set 7 | bambous virieux
# Processing Record 43 of Set 7 | mahebourg
# Processing Record 44 of Set 7 | vila do maio
# Processing Record 45 of Set 7 | jones
# Processing Record 46 of Set 7 | porosozero
# Processing Record 47 of Set 7 | goundam
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | douglas
# Processing Record 50 of Set 7 | singaraja
# Processing Record 1 of Set 8 | shreveport
# Processing Record 2 of Set 8 | porto novo
# Processing Record 3 of Set 8 | anchorage
# Processing Record 4 of Set 8 | vestmanna
# Processing Record 5 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 8 | golden
# Processing Record 7 of Set 8 | barcelos
# Processing Record 8 of Set 8 | makakilo city
# Processing Record 9 of Set 8 | axim
# Processing Record 10 of Set 8 | verkh-chebula
# Processing Record 11 of Set 8 | asau
# Processing Record 12 of Set 8 | zhangjiakou
# Processing Record 13 of Set 8 | vostok
# Processing Record 14 of Set 8 | oruro
# Processing Record 15 of Set 8 | moussoro
# Processing Record 16 of Set 8 | deputatskiy
# Processing Record 17 of Set 8 | korla
# Processing Record 18 of Set 8 | sandovo
# Processing Record 19 of Set 8 | cabo san lucas
# Processing Record 20 of Set 8 | daru
# Processing Record 21 of Set 8 | salta
# Processing Record 22 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 23 of Set 8 | pimentel
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | kangasala
# Processing Record 26 of Set 8 | beterou
# Processing Record 27 of Set 8 | juneau
# Processing Record 28 of Set 8 | constitucion
# Processing Record 29 of Set 8 | mitzic
# Processing Record 30 of Set 8 | ormond beach
# Processing Record 31 of Set 8 | alcala la real
# Processing Record 32 of Set 8 | pokhara
# Processing Record 33 of Set 8 | santa lucia
# Processing Record 34 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | caxito
# Processing Record 37 of Set 8 | gazanjyk
# Processing Record 38 of Set 8 | ostersund
# Processing Record 39 of Set 8 | pacific grove
# Processing Record 40 of Set 8 | algete
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | kindu
# Processing Record 43 of Set 8 | avera
# Processing Record 44 of Set 8 | manono
# Processing Record 45 of Set 8 | impfondo
# Processing Record 46 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 8 | celestun
# Processing Record 48 of Set 8 | adrar
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 50 of Set 8 | belmonte
# Processing Record 1 of Set 9 | broken hill
# Processing Record 2 of Set 9 | san juan
# Processing Record 3 of Set 9 | nalut
# Processing Record 4 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 9 | cabra
# Processing Record 6 of Set 9 | san patricio
# Processing Record 7 of Set 9 | zeya
# Processing Record 8 of Set 9 | shwebo
# Processing Record 9 of Set 9 | nokaneng
# Processing Record 10 of Set 9 | manta
# Processing Record 11 of Set 9 | semey
# Processing Record 12 of Set 9 | nemuro
# Processing Record 13 of Set 9 | chalchihuites
# Processing Record 14 of Set 9 | wahiawa
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | tukan
# Processing Record 17 of Set 9 | metro
# Processing Record 18 of Set 9 | bulgan
# Processing Record 19 of Set 9 | ugoofaaru
# Processing Record 20 of Set 9 | kobojango
# City not found. Skipping...
# Processing Record 21 of Set 9 | teocelo
# Processing Record 22 of Set 9 | jijiga
# Processing Record 23 of Set 9 | tabas
# Processing Record 24 of Set 9 | male
# Processing Record 25 of Set 9 | turukhansk
# Processing Record 26 of Set 9 | manzanillo
# Processing Record 27 of Set 9 | lircay
# Processing Record 28 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 29 of Set 9 | salamiyah
# Processing Record 30 of Set 9 | havelock
# Processing Record 31 of Set 9 | san policarpo
# Processing Record 32 of Set 9 | coihaique
# Processing Record 33 of Set 9 | nioro
# Processing Record 34 of Set 9 | biltine
# Processing Record 35 of Set 9 | lincoln
# Processing Record 36 of Set 9 | hervey bay
# Processing Record 37 of Set 9 | dwarka
# Processing Record 38 of Set 9 | nouadhibou
# Processing Record 39 of Set 9 | turbat
# Processing Record 40 of Set 9 | west wendover
# Processing Record 41 of Set 9 | aksha
# Processing Record 42 of Set 9 | mohpa
# Processing Record 43 of Set 9 | husavik
# Processing Record 44 of Set 9 | antofagasta
# Processing Record 45 of Set 9 | rafsanjan
# Processing Record 46 of Set 9 | davidson
# Processing Record 47 of Set 9 | staraya russa
# Processing Record 48 of Set 9 | chumphon
# Processing Record 49 of Set 9 | san quintin
# Processing Record 50 of Set 9 | sterlibashevo
# Processing Record 1 of Set 10 | lorengau
# Processing Record 2 of Set 10 | abu dhabi
# Processing Record 3 of Set 10 | pecos
# Processing Record 4 of Set 10 | saint stephen
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | sobotka
# Processing Record 7 of Set 10 | yuanping
# Processing Record 8 of Set 10 | ekibastuz
# Processing Record 9 of Set 10 | olavarria
# Processing Record 10 of Set 10 | kon tum
# Processing Record 11 of Set 10 | nuevo progreso
# Processing Record 12 of Set 10 | hualmay
# Processing Record 13 of Set 10 | san cristobal
# Processing Record 14 of Set 10 | am timan
# Processing Record 15 of Set 10 | xuddur
# Processing Record 16 of Set 10 | safaga
# Processing Record 17 of Set 10 | sambava
# Processing Record 18 of Set 10 | porto velho
# Processing Record 19 of Set 10 | omsukchan
# Processing Record 20 of Set 10 | kingman
# Processing Record 21 of Set 10 | abeche
# Processing Record 22 of Set 10 | san rafael
# Processing Record 23 of Set 10 | lata
# Processing Record 24 of Set 10 | klaksvik
# Processing Record 25 of Set 10 | vila franca do campo
# Processing Record 26 of Set 10 | marawi
# Processing Record 27 of Set 10 | kamalpur
# Processing Record 28 of Set 10 | kedrovyy
# Processing Record 29 of Set 10 | sfantu gheorghe
# Processing Record 30 of Set 10 | almenara
# Processing Record 31 of Set 10 | urucui
# Processing Record 32 of Set 10 | slobozia
# Processing Record 33 of Set 10 | bichena
# Processing Record 34 of Set 10 | kalmunai
# Processing Record 35 of Set 10 | beira
# Processing Record 36 of Set 10 | manuk mangkaw
# Processing Record 37 of Set 10 | alpena
# Processing Record 38 of Set 10 | qingdao
# Processing Record 39 of Set 10 | hami
# Processing Record 40 of Set 10 | sioux lookout
# Processing Record 41 of Set 10 | staunton
# Processing Record 42 of Set 10 | verkhoyansk
# Processing Record 43 of Set 10 | pisco
# Processing Record 44 of Set 10 | haileybury
# Processing Record 45 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 10 | bundaberg
# Processing Record 47 of Set 10 | trat
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | zhigansk
# Processing Record 50 of Set 10 | dukat
# Processing Record 1 of Set 11 | kingaroy
# Processing Record 2 of Set 11 | derzhavinsk
# Processing Record 3 of Set 11 | chicama
# Processing Record 4 of Set 11 | porto seguro
# Processing Record 5 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 11 | gravdal
# Processing Record 7 of Set 11 | tazmalt
# Processing Record 8 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 11 | fare
# Processing Record 10 of Set 11 | kargasok
# Processing Record 11 of Set 11 | chipinge
# Processing Record 12 of Set 11 | vardo
# Processing Record 13 of Set 11 | guerrero negro
# Processing Record 14 of Set 11 | vila
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | turkistan
# Processing Record 17 of Set 11 | garmsar
# Processing Record 18 of Set 11 | satipo
# Processing Record 19 of Set 11 | hirara
# Processing Record 20 of Set 11 | acqui terme
# Processing Record 21 of Set 11 | qaqortoq
# Processing Record 22 of Set 11 | yulara
# Processing Record 23 of Set 11 | luena
# Processing Record 24 of Set 11 | chikhli
# Processing Record 25 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 11 | paita
# Processing Record 27 of Set 11 | lamu
# Processing Record 28 of Set 11 | noumea
# Processing Record 29 of Set 11 | tottori
# Processing Record 30 of Set 11 | sabinas hidalgo
# Processing Record 31 of Set 11 | mapimi
# Processing Record 32 of Set 11 | urumqi
# Processing Record 33 of Set 11 | mount gambier
# Processing Record 34 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 11 | vrangel
# Processing Record 36 of Set 11 | mugma
# Processing Record 37 of Set 11 | san ramon
# Processing Record 38 of Set 11 | nanortalik
# Processing Record 39 of Set 11 | mackay
# Processing Record 40 of Set 11 | lang suan
# Processing Record 41 of Set 11 | aswan
# Processing Record 42 of Set 11 | natal
# Processing Record 43 of Set 11 | tabuk
# Processing Record 44 of Set 11 | yuancheng
# Processing Record 45 of Set 11 | shestakovo
# Processing Record 46 of Set 11 | twentynine palms
# Processing Record 47 of Set 11 | barcarena
# Processing Record 48 of Set 11 | karratha
# Processing Record 49 of Set 11 | port hawkesbury
# Processing Record 50 of Set 11 | vao
# Processing Record 1 of Set 12 | puerto escondido
# Processing Record 2 of Set 12 | marsabit
# Processing Record 3 of Set 12 | jieshi
# Processing Record 4 of Set 12 | dawlatabad
# Processing Record 5 of Set 12 | tadine
# Processing Record 6 of Set 12 | juruti
# Processing Record 7 of Set 12 | pangody
# Processing Record 8 of Set 12 | matagami
# Processing Record 9 of Set 12 | quatre cocos
# Processing Record 10 of Set 12 | broome
# Processing Record 11 of Set 12 | luwuk
# Processing Record 12 of Set 12 | manaure
# Processing Record 13 of Set 12 | bakreswar
# Processing Record 14 of Set 12 | nanchang
# Processing Record 15 of Set 12 | borgarnes
# Processing Record 16 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 12 | paragominas
# Processing Record 19 of Set 12 | lewistown
# Processing Record 20 of Set 12 | poso
# Processing Record 21 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 12 | la rioja
# Processing Record 23 of Set 12 | flinders
# Processing Record 24 of Set 12 | boyolangu
# Processing Record 25 of Set 12 | quelimane
# Processing Record 26 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 12 | nofoalii
# Processing Record 29 of Set 12 | lashio
# Processing Record 30 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 31 of Set 12 | berdigestyakh
# Processing Record 32 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 12 | cap malheureux
# Processing Record 34 of Set 12 | ankazoabo
# Processing Record 35 of Set 12 | kangaatsiaq
# Processing Record 36 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 12 | loucna nad desnou
# Processing Record 38 of Set 12 | lasa
# Processing Record 39 of Set 12 | chapada dos guimaraes
# Processing Record 40 of Set 12 | middle island
# Processing Record 41 of Set 12 | gunnedah
# Processing Record 42 of Set 12 | gopalpur
# Processing Record 43 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 44 of Set 12 | porto da folha
# Processing Record 45 of Set 12 | port macquarie
# Processing Record 46 of Set 12 | yatou
# Processing Record 47 of Set 12 | arlit
# Processing Record 48 of Set 12 | abadiania
# Processing Record 49 of Set 12 | alice springs
# Processing Record 50 of Set 12 | zaraza
# Processing Record 1 of Set 13 | taiyuan
# Processing Record 2 of Set 13 | osterburg
# Processing Record 3 of Set 13 | mutsu
# Processing Record 4 of Set 13 | osoyoos
# Processing Record 5 of Set 13 | uarini
# Processing Record 6 of Set 13 | clarence town
# Processing Record 7 of Set 13 | tongliao
# Processing Record 8 of Set 13 | jardim
# Processing Record 9 of Set 13 | morant bay
# Processing Record 10 of Set 13 | maningrida
# Processing Record 11 of Set 13 | new ulm
# Processing Record 12 of Set 13 | ossora
# Processing Record 13 of Set 13 | yaounde
# Processing Record 14 of Set 13 | obigarm
# Processing Record 15 of Set 13 | hede
# Processing Record 16 of Set 13 | pangnirtung
# Processing Record 17 of Set 13 | silver city
# Processing Record 18 of Set 13 | ambon
# Processing Record 19 of Set 13 | moroni
# Processing Record 20 of Set 13 | santo antonio
# Processing Record 21 of Set 13 | bar-le-duc
# Processing Record 22 of Set 13 | istok
# Processing Record 23 of Set 13 | olmos
# Processing Record 24 of Set 13 | darhan
# Processing Record 25 of Set 13 | kayankulam
# Processing Record 26 of Set 13 | mundo nuevo
# Processing Record 27 of Set 13 | tomohon
# Processing Record 28 of Set 13 | igrim
# Processing Record 29 of Set 13 | jinchang
# Processing Record 30 of Set 13 | soyo
# Processing Record 31 of Set 13 | chiredzi
# Processing Record 32 of Set 13 | kutum
# Processing Record 33 of Set 13 | ypsonas
# Processing Record 34 of Set 13 | ola
# Processing Record 35 of Set 13 | kamyshin
# Processing Record 36 of Set 13 | grand gaube
# Processing Record 37 of Set 13 | neveklov
# Processing Record 38 of Set 13 | kyabe
# Processing Record 39 of Set 13 | karaton
# Processing Record 40 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 13 | garowe
# Processing Record 42 of Set 13 | binabalian
# Processing Record 43 of Set 13 | karmana
# City not found. Skipping...
# Processing Record 44 of Set 13 | bobrovka
# Processing Record 45 of Set 13 | bonfim
# Processing Record 46 of Set 13 | adre
# Processing Record 47 of Set 13 | rehoboth
# Processing Record 48 of Set 13 | livingston
# Processing Record 49 of Set 13 | portobelo
# Processing Record 50 of Set 13 | presidencia roque saenz pena
# Processing Record 1 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 14 | tobe
# Processing Record 3 of Set 14 | fomboni
# Processing Record 4 of Set 14 | balabac
# Processing Record 5 of Set 14 | pacifica
# Processing Record 6 of Set 14 | bindura
# Processing Record 7 of Set 14 | okato
# Processing Record 8 of Set 14 | mantua
# Processing Record 9 of Set 14 | plettenberg bay
# Processing Record 10 of Set 14 | dawei
# Processing Record 11 of Set 14 | navolato
# Processing Record 12 of Set 14 | alcudia
# Processing Record 13 of Set 14 | spearfish
# Processing Record 14 of Set 14 | kijang
# Processing Record 15 of Set 14 | port-gentil
# Processing Record 16 of Set 14 | altay
# Processing Record 17 of Set 14 | san francisco
# Processing Record 18 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 14 | buin
# Processing Record 20 of Set 14 | batemans bay
# Processing Record 21 of Set 14 | vannes
# Processing Record 22 of Set 14 | tapanatepec
# City not found. Skipping...
# Processing Record 23 of Set 14 | sri aman
# Processing Record 24 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 14 | camacari
# Processing Record 26 of Set 14 | chernaya kholunitsa
# Processing Record 27 of Set 14 | santa cruz
# Processing Record 28 of Set 14 | san-pedro
# Processing Record 29 of Set 14 | show low
# Processing Record 30 of Set 14 | eureka
# Processing Record 31 of Set 14 | tawang
# Processing Record 32 of Set 14 | surt
# Processing Record 33 of Set 14 | rajbiraj
# Processing Record 34 of Set 14 | santa rosa
# Processing Record 35 of Set 14 | mayo
# Processing Record 36 of Set 14 | fairbanks
# Processing Record 37 of Set 14 | high level
# Processing Record 38 of Set 14 | forestville
# Processing Record 39 of Set 14 | ust-kuyga
# Processing Record 40 of Set 14 | tiffin
# Processing Record 41 of Set 14 | torredonjimeno
# Processing Record 42 of Set 14 | menongue
# Processing Record 43 of Set 14 | sendafa
# Processing Record 44 of Set 14 | lamar
# Processing Record 45 of Set 14 | pierre
# Processing Record 46 of Set 14 | mount pleasant
# Processing Record 47 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 14 | grand island
# Processing Record 49 of Set 14 | hiranagar
# Processing Record 50 of Set 14 | jilib
# Processing Record 1 of Set 15 | foz
# Processing Record 2 of Set 15 | coetupo
# City not found. Skipping...
# Processing Record 3 of Set 15 | naze
# Processing Record 4 of Set 15 | ust-ilimsk
# Processing Record 5 of Set 15 | wexford
# Processing Record 6 of Set 15 | qasigiannguit
# Processing Record 7 of Set 15 | kilindoni
# Processing Record 8 of Set 15 | sharan
# Processing Record 9 of Set 15 | gympie
# Processing Record 10 of Set 15 | kondagaon
# Processing Record 11 of Set 15 | richards bay
# Processing Record 12 of Set 15 | sharanga
# Processing Record 13 of Set 15 | izumo
# Processing Record 14 of Set 15 | kushima
# Processing Record 15 of Set 15 | san andres
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred      ZA -33.5906   26.8910     66.99        95          98
# 1     Jamestown      US  42.0970  -79.2353     15.01        73          90
# 2       College      US  64.8569 -147.8028     -9.00        76          20
# 3  Puerto Ayora      EC  -0.7393  -90.3518     82.40        74          75
# 4     Carnarvon      AU -24.8667  113.6333     75.20       100          40
# 5        Albany      US  42.6001  -73.9662     30.00        72         100
# 6   Clyde River      CA  70.4692  -68.5914     -4.00        92          75
# 7        Faanui      PF -16.4833 -151.7500     81.10        77           2
# 8       Mataura      NZ -46.1927  168.8643     67.14        50          98
# 9      Thompson      CA  55.7435  -97.8558    -25.60        68          75
#
#    Wind Speed Current Description
# 0        9.89     overcast clouds
# 1       14.97          light snow
# 2        2.35          few clouds
# 3       12.66          light rain
# 4       10.36    scattered clouds
# 5       10.13          light snow
# 6       20.71          light snow
# 7       13.00           clear sky
# 8        3.09     overcast clouds
# 9       17.27                snow

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
